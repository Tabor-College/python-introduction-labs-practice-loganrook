# %%
#data set
sensor_readings = [
    22.5, 22.7, 22.6, 22.9,
    23.1, 23.4, 23.8, 24.0,
    24.3, 24.8
]

# %%
#Lauryns cell-1
sensor_readings = [
    22.5, 22.7, 22.6, 22.9,
    23.1, 23.4, 23.8, 24.0,
    24.3, 24.8
]

for value in sensor_readings:
  print (value)
# Out:
# 22.5
# 22.7
# 22.6
# 22.9
# 23.1
# 23.4
# 23.8
# 24.0
# 24.3
# 24.8

# %%
#Lauryns Cell-2
it = iter (sensor_readings)
next(it)
next(it)
next(it)
# Out:
# 22.6

# %%
#Lauryns Cell-3
def sensor_stream(data):
    for value in data:
        print("Producing:", value)
        yield value
stream = sensor_stream(sensor_readings)
next(stream)
next(stream)
next(stream)
# Out:
# Producing: 22.5
# Producing: 22.7
# Producing: 22.6
# 22.6

# %%
#Amari's cell 1
def normal_func():
  print ("Start")
  return 1
  print ("End")

normal_func()

def gen_func():
  print("Start")
  yield 1
  print("Middle")
  yield 2
  print ("End")

g = gen_func()

next(g)
next(g)
next(g)
# Out:
# Start
# Start
# 1

# %%
next(g)
# Out:
# Middle
# 2

# %%
next(g)
# Out:
# End
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# /tmp/ipython-input-4253931490.py in <cell line: 0>()
# ----> 1 next(g)
#
# StopIteration:

# %%
#Amari's Cell 2
def counter():
  x = 0
  while True:
    yield x
    x += 1

c = counter()
next(c)
next(c)
next(c)
# Out:
# 2

# %%
#LOGANS CELL
#part 6
def high_temp_filter(stream, threshold):
  for value in stream:
    print("Filtering:", value)
    if value > threshold:
      yield value

stream = sensor_stream(sensor_readings)
filtered = high_temp_filter(stream, 23.0)

next(filtered)
next(filtered)
# Out:
# Producing: 22.5
# Filtering: 22.5
# Producing: 22.7
# Filtering: 22.7
# Producing: 22.6
# Filtering: 22.6
# Producing: 22.9
# Filtering: 22.9
# Producing: 23.1
# Filtering: 23.1
# Producing: 23.4
# Filtering: 23.4
# 23.4

# %%
#WADES CELL
# Part 7.1
## __init__, __str__, repr__

class User:
  def __init__(self, name, age):
    self.name = name
    self.age= age
  def __str__(self):
    return f"{self.name}, age{self.age}"
  def __repr__(self):
    return f"User(name={self.name!r}, age={self.age})"

u = User("Alice", 21)
print(u)
u

#7.2 Truth and Size
## __len,__bool__

class Cart:
  def __init__(self, items):
    self.items = items
  def __len__(self):
    return len(self.items)
  def __bool__(self):
    return len(self.items) > 0

cart = Cart(["apple", "banana"])
empty_cart = Cart([])

len(cart)
bool(cart)

if cart:
  print("Cart has items")

#7.3 Indexing and Iteration
## __getitem__,__iter__,__next__

class Log:
  def __init__(self, data):
    self.data = data
  def __getitem__(self, index):
    return self.data[index]

log = Log([10, 20, 30, 40])
log[0]
log[2]

for x in log:
  print(x)

#7.4 Comparison and Operators
## __eq__,__lt__,__add__

class Score:
  def __init__(self, value):
    self.value = value

  def __eq__(self, other):
    return self.value == other.value

  def __lt__(self, other):
    return self.value < other.value

  def __add__(self, other):
    return Score(self.value + other.value)

a = Score(10)
b = Score(20)

a == b
a < b

c = a + b
c.value
# Out:
# Alice, age21
# Cart has items
# 10
# 20
# 30
# 40
# 30

# %%
#LOGANS CELL
#part 8
gen = sensor_stream(sensor_readings)

iter(gen) is gen
next(gen)
# Out:
# Producing: 22.5
# 22.5

# %% [markdown]
# # Lab 3 Friday Work

# %%
#lab 1.1 simple closure (data persists)
def outer():
    x = 10
    def inner():
        print("x =", x)
    return inner

f = outer()
f()
f()
# Out:
# x = 10
# x = 10

# %%
#lab 1.2 closure with changing state
def counter():
  count = 0
  def inc():
    nonlocal count
    count +=1
    print("count =", count)
  return inc

c = counter()
c()
c()
c()
# Out:
# count = 1
# count = 2
# count = 3

# %%
#lab 1.3 prove where the data lives
print(c.__closure__)
print(c.__closure__[0].cell_contents)
# Out:
# (<cell at 0x7f55c00e29b0: int object at 0xb1d528>,)
# 3

# %%
#lab 2.1 basic decorators
def my_decorator(func):
  def wrapper():
    print("Before function")
    func()
    print("After function")
  return wrapper

@my_decorator
def greet():
  print("Hello!")

greet()
# Out:
# Before function
# Hello!
# After function

# %%
#lab 2.2 decorator vs wrapper (IMPORTANT)
def demo_decorator(func):
  print("DECORATOR runs (definition time)")
  def wrapper():
    print("WRAPPER start")
    func()
    print("WRAPPER end")
  return wrapper

@demo_decorator
def say_hi():
  print("HI")

say_hi()
# Out:
# DECORATOR runs (definition time)
# WRAPPER start
# HI
# WRAPPER end

# %%
#lab 2.3 inspect the decorated function
print(say_hi)
print(say_hi.__closure__)
# Out:
# <function demo_decorator.<locals>.wrapper at 0x7f55933c9ee0>
# (<cell at 0x7f5593f05810: function object at 0x7f55933cac00>,)

# %%
#lab 3 decorator with arguments
def log_calls(func):
  def wrapper(*args):
    print("Calling with args:", args)
    return func(*args)
  return wrapper

@log_calls
def add(a, b):
  return a + b

print(add(3, 4))
print(add(10, 20))
# Out:
# Calling with args: (3, 4)
# 7
# Calling with args: (10, 20)
# 30

# %%
#lab 4.1 closure = data memory
def make_multiplier(n):
  def multiply(x):
    return x * n
  return multiply

double = make_multiplier(2)
triple = make_multiplier(3)

print(double(5))
print(triple(5))
# Out:
# 10
# 15

# %%
#lab 4.2 decorator = behavior wrapping
def loud(func):
  def wrapper():
    print("LOUD MODE")
    func()
  return wrapper

@loud
def speak():
  print("hello")

speak()
# Out:
# LOUD MODE
# hello
