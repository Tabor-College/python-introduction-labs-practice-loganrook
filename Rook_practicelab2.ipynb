# %%
#problem 1
#prediction: "A", then "C"
print("A")
print("B")
print("C")
# Out:
# A
# B
# C

# %%
#problem 2
#prediction: 10
x = 10
y = x
x = 20
print(y)
# Out:
# 10

# %%
#problem 3
#prediction: 6
x = 5
x = x + 1
print(x)
# Out:
# 6

# %%
#problem 4
#prediction: "before", "inside", 5, "after"
def add(a, b):
    print("inside")
    return a + b

print("before")
add(2, 3)
print("after")
# Out:
# before
# inside
# after

# %%
#problem 4 observation: I wrongly predicted 5 would be printed, forgot that the return would need to be assigned an object

# %%
#problem 5
#prediction: something will print
def make():
    x = [1, 2]
    return x

lst = make()
print(lst)
# Out:
# [1, 2]

# %%
#problem 6
#prediction: [1,2,3], [9,10]
lst = [1,2]
lst.append(3)
print(lst)

lst = [1,2]
lst = [9,10]
print(lst)
# Out:
# [1, 2, 3]
# [9, 10]

# %%
#problem 7
#prediction: 10
def f(x):
    x = x + 1

a = 10
f(a)
print(a)
# Out:
# 10

# %%
#problem 8
#prediction: 3 lines
for i in [1,2,3]:
    print(i)
# Out:
# 1
# 2
# 3

# %%
#problem 9
#prediction: error on last line
it = iter([1,2])
print(next(it))
print(next(it))
print(next(it))
# Out:
# 1
# 2
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[11], line 6
#       4 print(next(it))
#       5 print(next(it))
# ----> 6 print(next(it))
#
# StopIteration:

# %%
#problem 10
#prediction: yes, something will print
def demo():
    print("A")
    yield 1
    print("B")

# %%
#problem 10 observation: I was not correct in my prediction, as i wrongly assumed how yield would work

# %%
#problem 11
#prediction: "B", and then "A"
g = demo()
print(next(g))
print(next(g))
# Out:
# A
# 1
# B
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[15], line 5
#       3 g = demo()
#       4 print(next(g))
# ----> 5 print(next(g))
#
# StopIteration:

# %%
#problem 11 observation: The demo funtion and next stuff doesnt work at all like how i thought it would.

# %%
#problem 12
#prediction: it will crash
def outer():
    x = 10
    def inner():
        return x
    return inner

f = outer()
print(f())
# Out:
# 10

# %%
#problem 12 observation: I reallt thought that the "f()" would throw an error since f was only ever "f" and not "f()"

# %%
#problem 13
#prediction: 1 line
def deco(fn):
    def wrapper():
        print("before")
        fn()
        print("after")
    return wrapper

@deco
def hello():
    print("hello")

hello()
# Out:
# before
# hello
# after

# %%
#problem 13 observation: I did not realize how decorators worked, but I do understand now after running the code

# %%
#problem 14
#prediction: should print something
class A:
    x = 10

a = A()
print(a.x)
# Out:
# 10

# %%
class MyRange:
    def __iter__(self):
        return self
    def __next__(self):
        raise StopIteration

for x in MyRange():
    print(x)

# %%
#problem 15 observation: rereading the code, there is no "x" for Myrange to operate off of.
